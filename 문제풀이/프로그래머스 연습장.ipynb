# %%
import math

# %%
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     ceil(x, /)
#         Return the ceiling of x as an Integral.
#
#         This is the smallest integer >= x.
#
#     copysign(x, y, /)
# ...

# %%
math.modf(4.3)
# Out:
# (0.2999999999999998, 4.0)

# %%
def solution(array):
    sorted(array)
    counted = []
    for i in range(len(array)):
        if i == 0:
            counted.append(array[i]) 
        else:
            counted.append(array.count(i))
            
    return max(counted)

# %%
solution([1,2,4,4,4,3])
# Out:
# 3

# %%
array = [1,2,3,3,4,4,4]
counted = []
    #if len(array) == 1:
    #    return array[0]
for i in range(len(array)-1):
    if array[i+1]==array[i]:
        counted.append(array[i])
    else:
        continue
    #counted = set(counted)
    #if len(counted) > 1:
    #    return -1

# %%
counted
# Out:
# [3, 4, 4]

# %%
def odd_num(n):
    answer = []
    for i in range(n):
        if i%2==1:
            answer.append(i)
        else:
            continue
    return answer

# %%
odd_num(3)
# Out:
# [1]

# %%
def angles(angle):
    answer = (angle // 90) * 2 + (angle % 90 > 0) * 1
    return answer

# %%
angles(80)
# Out:
# 1

# %%
80 % 90 > 0
# Out:
# True

# %%
def heigh(array, height):
    array.append(height)
    array.sort(reverse=True)
    return array.index(height)  #height가 몇 번째인지 출력 : height보다 큰 값들의 수를 알 수 있게 됨.

# %%
heigh([120,140,190], 180)
# Out:
# 1

# %%
n = 3

for i in range(3):
    texts = my_string[i] * n

sum(texts)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-667708070d4c> in <module>
#       4     texts = my_string[i] * n
#       5
# ----> 6 sum(texts)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
my_string = 'string'
my_string[0] * 3
# Out:
# 'sss'

# %%
a, b = map(int, input().split())
print(a+b)
# Out:
# 3 2
# 5

# %% [markdown]
# ## 최빈값 구하기

# %%
leest = [0,2,4,4,4,5,5,5,6]
set(enumerate(leest))
# Out:
# {(0, 0), (1, 2), (2, 4), (3, 4), (4, 4), (5, 5), (6, 5), (7, 5), (8, 6)}

# %%
def mosthave(array):
    while len(array) != 0:
        for i, a in enumerate(set(array)):
            array.remove(a)
        if i == 0: return a
    return -1

# %%
from collections import Counter

def modefinder(numbers):
    c = Counter(numbers)
    order = c.most_common()
    maximum = order[0][1]

    modes = []
    for num in order:
        if num[1] == maximum:
            modes.append(num[0])
    return modes

# %% [markdown]
# ## 피자나눠먹기 2 (다시 풀어볼 것)
# (while문 이용 - 검색으로 답을 얻었으니 다시 풀어볼 것)
#
# 문제 설명
# 머쓱이네 피자가게는 피자를 여섯 조각으로 잘라 줍니다. 피자를 나눠먹을 사람의 수 n이 매개변수로 주어질 때, n명이 주문한 피자를 남기지 않고 모두 같은 수의 피자 조각을 먹어야 한다면 최소 몇 판을 시켜야 하는지를 return 하도록 solution 함수를 완성해보세요.
#
# 제한사항
# 1 ≤ n ≤ 100
#
# 입출력 예
# n	result
# 6	1
# 10	5
# 4	2

# %%
def pizza_div2(n):
    pizza = 6
    while pizza % n != 0:
        pizza += 6
    return pizza // 6

# %%
pizza_div2(4)
# Out:
# 2

# %%
leest = ["We", "are", "the", "world!"]
len(leest[0])
answer=[]
for i in leest:
    answer.append(len(i))
print(answer)

# for문에 넣었을 때 range(len(leest)) 와 leest의 차이가?
# leest를 쓰려면 len(i)로 써야 한다. len(leest[i])를 쓴다면 range(len(leest))로
# Out:
# [2, 3, 3, 6]

# %%
my_string = 'hello'
n=3
result = []
for i in range(len(my_string)):
    result.append(my_string[i] * n)
answer = ''
for j in range(len(result)):
    answer += result[j]

# %%
del result
del answer

# %%
answer
# Out:
# 'hhheeellllllooo'

# %%
''.join(i*n for i in my_string)
# Out:
# 'hhheeellllllooo'

# %%
my_string = 'asdf'
letter = 'f'
if str(letter) in str(my_string):
    del letter
my_string
# Out:
#   File "<ipython-input-2-4f23ad13bd6f>", line 4
#     del letter = my_string
#                ^
# SyntaxError: invalid syntax

# %%
# 비트 연산자 a << b
2 << 10
# Out:
# 2048

# %%
import math
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     ceil(x, /)
#         Return the ceiling of x as an Integral.
#
#         This is the smallest integer >= x.
#
#     comb(n, k, /)
# ...

# %%
streng = 'sInfkgK'
streng[1].lower()
# Out:
# 'i'

# %%
leest = [1, 8, 3]
[max(leest), leest.index(max(leest))]
# Out:
# [8, 1]

# %% [markdown]
# ## 약수 구하기

# %%
n = 17
i = 1
answeer = []
while n % i == int(n%1) :
    answeer.append(i)
    i += 1
else:
    i += 1

answeer
# Out:
# [1]

# %%
my_string.replace(letter, '')

# %%
help(enumerate)

# %%
emergency = [3, 76, 24]	
answeer = [1 for i in range(len(emergency))] # 1로 채워진 리스트. 길이는 emergency와 동일
n = 1
for i in range(len(emergency)):
    for j in range(len(emergency)):
        if emergency[i] > emergency[j]:
            answeer[j] += 1
        else:
            continue
answeer
# Out:
# [3, 1, 2]

# %%
list('1121')
# Out:
# ['1', '1', '2', '1']

# %%
n = 20
len([i*j for i in range(1, n+1) for j in range(1, n+1) if i*j==n])
# Out:
# 6

# %%
def ordpar(n):
    answer = 0
    for i in range(n+1):
        for j in range(n+1):
            if i * j == n:
                answer += 1
            if i * j > n:
                pass
    return answer

# %%
ordpar(100)

# 시간초과 줄일 방법은?
# Out:
# 9

# %%
age = 23
age = str(age)
age_ex = {}
for i, j in enumerate(['a','b','c','d','e','f','g','h','i','j']):
    replace
    replace(age[i], age[j])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-aaba71db9411> in <module>
#       6
#       7 age = str(age)
# ----> 8 age.replace(age[0], age_ex.values())
#
# TypeError: replace() argument 2 must be str, not dict_values

# %%
age = str(age)
age = list(age)
age
# Out:
# ['2', '3']
